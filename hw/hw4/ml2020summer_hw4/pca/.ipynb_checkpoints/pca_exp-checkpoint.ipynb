# %% [markdown]
# # Principal Component Analysis
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement **Principal Component Analysis** and apply it to **restore rotated CAPTCHA**
# - play with **Eigenface** by applying PCA on a real world face dataset
# - use PCA to do **dimension reduction**. Evaluate the loss of information qualitatively and quantitatively
#
# Please note that **YOU CANNOT USE ANY MACHINE LEARNING PACKAGE SUCH AS SKLEARN** for any homework, unless you are asked to.

# %%
# some basic imports
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Now let's hack the rotated CAPTCHA!

# %%
from hack_pca import hack_pca

# Hack different images yourself
img = hack_pca('1.gif')
plt.imshow(img)
# Out:
# -29.951595312425077

# %%
img = hack_pca('2.gif')
plt.imshow(img)
# Out:
# 29.951595312425084

# %%
img = hack_pca('3.gif')
plt.imshow(img)
# Out:
# -45.0

# %%
img = hack_pca('4.gif')
plt.imshow(img)
# Out:
# -45.0

# %%
img = hack_pca('5.gif')
plt.imshow(img)
# Out:
# 15.000488224109631

# %% [markdown]
# ## Apply PCA on face image

# %%
# load data
ORL_data = sio.loadmat('ORL_data.mat')
fea_Train = ORL_data['fea_Train']
gnd_Train = ORL_data['gnd_Train'].reshape(-1)
fea_Test = ORL_data['fea_Test']
gnd_Test = ORL_data['gnd_Test'].reshape(-1)
# YOUR CODE HERE

# 1. Feature preprocessing
# begin answer
fea_Train = fea_Train - np.mean(fea_Train, axis = 0)
fea_Test = fea_Test - np.mean(fea_Test, axis = 0)
# end answer
from show_face import show_face
show_face(fea_Train)

# %%
# 2. Run PCA
# begin answer
from pca import PCA
vec, val = PCA(fea_Train)
# end answer
# 3. Visualize eigenface
# begin answer
show_face(vec.T)
# end answer

# %%
# 4. Project data on to low dimensional space
# begin answer
from knn import knn
for i in [8,16,32,64,128]:
    emb_Train = np.matmul(fea_Train, vec[:, :i])
    emb_Test = np.matmul(fea_Test, vec[:, :i])
# end answer

# 5. Run KNN in low dimensional space
# begin answer
    prediction = knn(emb_Test, emb_Train, gnd_Train, 1)
    accuracy = np.sum(prediction == gnd_Test) / prediction.shape[0]
    print('dimensional:', i, 'accuracy:',  1- accuracy)
# end answer
# 6. Recover face images form low dimensional space, visualize them
# begin answer
    show_face(np.matmul(emb_Test, vec[:, :i].T))
# end answer
# Out:
# dimensional: 8 accuracy: 0.745
# dimensional: 16 accuracy: 0.825
# dimensional: 32 accuracy: 0.845
# dimensional: 64 accuracy: 0.865
# dimensional: 128 accuracy: 0.865

# %% [markdown]
# ## You are encouraged to apply LDA on this dataset!

# %%
from LDA import LDA

# Your code here
# begin answer
vec, val = LDA(fea_Train, gnd_Train)
for i in [8, 16, 32, 64, 128]:
    emb_Train = np.matmul(fea_Train, vec[:, :i])
    emb_Test = np.matmul(fea_Test, vec[:, :i])
    prediction = knn(emb_Test, emb_Train, gnd_Train, 1)
    accuracy = np.sum(prediction == gnd_Test) / prediction.shape[0]
    print('dimensional:', i, 'accuracy:', 1 - accuracy)
# end answer
# Out:
# dimensional: 8 accuracy: 0.11499999999999999
# dimensional: 16 accuracy: 0.05500000000000005
# dimensional: 32 accuracy: 0.04500000000000004
# dimensional: 64 accuracy: 0.030000000000000027
# dimensional: 128 accuracy: 0.030000000000000027
